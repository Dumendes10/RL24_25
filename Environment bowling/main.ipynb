# %% [markdown]
# Project Reinforcement Learning

# %%
import gymnasium as gym
import ale_py
import time

from utils import *
from model import *
from preprocessing import *

# %%
gym.register_envs(ale_py)

env = gym.make("ALE/Bowling-v5", render_mode="human")
observation, info = env.reset(seed=42)

print("Observation shape:", observation.shape)
print("Observation data type:", observation.dtype)
print("Action space:", env.action_space)

num_rounds = 1
for round_num in range(num_rounds):
    print(f"\n--- Round {round_num + 1} ---")
    terminated = False
    truncated = False
    total_reward = 0
    step = 0
    while not terminated and not truncated:
        action = env.action_space.sample()
        next_observation, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        step += 1
        print(f"Step: {step}, Action: {action}, Reward: {reward}, Terminated: {terminated}, Truncated: {truncated}")
        env.render()
        time.sleep(0.1)  # Add a small delay to see what's happening

        # In Bowling, an episode typically ends after all frames are played.
        # We'll rely on the environment's 'terminated' flag to signal the end of the game.
        if terminated or truncated:
            print(f"Round {round_num + 1} finished after {step} steps with total reward: {total_reward}")
            observation, info = env.reset()
            break

    if round_num == num_rounds - 1:
        print("\n--- End of 10 Rounds ---")
        break

env.close()
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.0+dfae0bd)
# [Powered by Stella]
# Observation shape: (210, 160, 3)
# Observation data type: uint8
# Action space: Discrete(6)
#
# --- Round 1 ---
# Step: 1, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 2, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 3, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 4, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 5, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 6, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 7, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 8, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 9, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 10, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 11, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 12, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 13, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 14, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 15, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 16, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 17, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 18, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 19, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 20, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 21, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 22, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 23, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 24, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 25, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 26, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 27, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 28, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 29, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 30, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 31, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 32, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 33, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 34, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 35, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 36, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 37, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 38, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 39, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 40, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 41, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 42, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 43, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 44, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 45, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 46, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 47, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 48, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 49, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 50, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 51, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 52, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 53, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 54, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 55, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 56, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 57, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 58, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 59, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 60, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 61, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 62, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 63, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 64, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 65, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 66, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 67, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 68, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 69, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 70, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 71, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 72, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 73, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 74, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 75, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 76, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 77, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 78, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 79, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 80, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 81, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 82, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 83, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 84, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 85, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 86, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 87, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 88, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 89, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 90, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 91, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 92, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 93, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 94, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 95, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 96, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 97, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 98, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 99, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 100, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 101, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 102, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 103, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 104, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 105, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 106, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 107, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 108, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 109, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 110, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 111, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 112, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 113, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 114, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 115, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 116, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 117, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 118, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 119, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 120, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 121, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 122, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 123, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 124, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 125, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 126, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 127, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 128, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 129, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 130, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 131, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 132, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 133, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 134, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 135, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 136, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 137, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 138, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 139, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 140, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 141, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 142, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 143, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 144, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 145, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 146, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 147, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 148, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 149, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 150, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 151, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 152, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 153, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 154, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 155, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 156, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 157, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 158, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 159, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 160, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 161, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 162, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 163, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 164, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 165, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 166, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 167, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 168, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 169, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 170, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 171, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 172, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 173, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 174, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 175, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 176, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 177, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 178, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 179, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 180, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 181, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 182, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 183, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 184, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 185, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 186, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 187, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 188, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 189, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 190, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 191, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 192, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 193, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 194, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 195, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 196, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 197, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 198, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 199, Action: 2, Reward: 0.0, Terminated: False, Truncated: False
# Step: 200, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 201, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step: 202, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 203, Action: 5, Reward: 0.0, Terminated: False, Truncated: False
# Step: 204, Action: 1, Reward: 0.0, Terminated: False, Truncated: False
# Step:
Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# Step: 398, Action: 3, Reward: 0.0, Terminated: False, Truncated: False
# Step: 399, Action: 4, Reward: 0.0, Terminated: False, Truncated: False
# Step: 400, Action: 0, Reward: 0.0, Terminated: False, Truncated: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 32
#      30 print(f"Step: {step}, Action: {action}, Reward: {reward}, Terminated: {terminated}, Truncated: {truncated}")
#      31 env.render()
# ---> 32 time.sleep(0.1)  # Add a small delay to see what's happening
#      34 # In Bowling, an episode typically ends after all frames are played.
#      35 # We'll rely on the environment's 'terminated' flag to signal the end of the game.
#      36 if terminated or truncated:
#
# KeyboardInterrupt:

# %%
import gymnasium as gym
import ale_py  # needed to register ALE envs

gym.register_envs(ale_py)  # required for Gymnasium to recognize ALE/Bowling-v5

env = gym.make("ALE/Bowling-v5", render_mode="rgb_array")

# %% [markdown]
# utils call e/ou preprocessing

# %% [markdown]
# This cell creates the Atari Bowling environment and wraps it with a custom preprocessing class. The environment is configured to return RGB frames (`render_mode="rgb_array"`), which are then converted to grayscale, resized to 84×84 pixels, and stacked across the last 4 frames. This processed output is suitable for training deep reinforcement learning agents that require compact, temporally-aware visual input.

# %%
raw_env = gym.make("ALE/Bowling-v5", render_mode="rgb_array")
env = ManualPreprocessWrapper(raw_env, frame_stack=4)

# %% [markdown]
# This cell initializes the Rainbow DQN agent by creating a neural network that takes 4 stacked grayscale frames of size 84×84 as input and outputs action-value distributions for the Atari Bowling environment. It also configures the model to run on a GPU if available, enabling efficient training.

# %%
from model import RainbowDQN
import torch

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define input shape and action space
input_shape = (4, 84, 84)  # 4 stacked frames of 84x84 grayscale images
num_actions = env.action_space.n  # number of discrete actions in the env

# Main agent (online network)
agent = RainbowDQN(input_shape, num_actions).to(device)

# Target network (used in Bellman updates)
target_agent = RainbowDQN(input_shape, num_actions).to(device)
target_agent.load_state_dict(agent.state_dict())  # Copy weights initially
target_agent.eval()  # Disable noisy layers during inference
# Out:
# RainbowDQN(
#   (features): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (value_stream): Sequential(
#     (0): NoisyLinear()
#     (1): ReLU()
#     (2): NoisyLinear()
#   )
#   (advantage_stream): Sequential(
#     (0): NoisyLinear()
#     (1): ReLU()
#     (2): NoisyLinear()
#   )
#   (softmax): Softmax(dim=2)
# )

# %% [markdown]
# Exploration vs. Exploitation:
# - This project uses Noisy Networks (Noisy Nets) for exploration, a feature of the Rainbow DQN algorithm. Rather than manually decaying an ε in ε-greedy policies, Noisy Nets inject learnable, parameterized noise into the model’s layers. This encourages diverse behavior early in training and naturally reduces randomness as the agent becomes more confident, effectively balancing exploration and exploitation over time.

# %%
from torch.amp import autocast  # ✅ NEW AMP import
from torch.cuda.amp import GradScaler

# -------------------- CONFIGURATION --------------------
TOTAL_TIMESTEPS = 30_000
BATCH_SIZE = 64
LEARNING_RATE = 2e-4
EVAL_EVERY = 25_000
MAX_STEPS_PER_EPISODE = 1000
N_STEP = 2
GAMMA = 0.99
WARMUP_STEPS = 500
TARGET_UPDATE_FREQ = 20_000
LOG_FREQ = 5000
REWARD_LOG_FILE = "rainbow_bowling_rewards.csv"
SUCCESS_THRESHOLD = 5.0
# ------------------------------------------------------

# -------------------- SETUP --------------------
buffer = PrioritizedReplayBuffer()
n_step_buffer = deque(maxlen=N_STEP)
n_gamma = GAMMA ** N_STEP

state, _ = env.reset()
episode_reward = 0
episode_count = 0
episode_step_count = 0
best_reward = float('-inf')

optimizer = torch.optim.Adam(agent.parameters(), lr=LEARNING_RATE)
scaler = GradScaler()

for t in range(TOTAL_TIMESTEPS):
    if t < WARMUP_STEPS:
        action = env.action_space.sample()
    else:
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        action = agent.act(state_tensor)

    next_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    episode_step_count += 1
    done = done or (episode_step_count >= MAX_STEPS_PER_EPISODE)

    if reward != 0:
        print(f"🔥 Non-zero reward at step {t}: {reward}")

    n_step_buffer.append((state, action, reward, next_state, done))
    if len(n_step_buffer) == N_STEP:
        ns, na, nr, ns2, nd = compute_n_step_transition(n_step_buffer)
        buffer.add(ns, na, nr, ns2, nd)

    episode_reward, episode_count, state = track_reward(
        episode_reward, episode_count, reward, done, t, env, next_state
    )

    if done:
        episode_step_count = 0
        n_step_buffer.clear()

    # Training step
    if len(buffer) > BATCH_SIZE:
        s, a, r, s2, d, weights, idxs = buffer.sample(BATCH_SIZE)
        s = s.to(device)
        s2 = s2.to(device)
        a = a.to(device)
        r = r.to(device)
        d = d.to(device)
        weights = weights.to(device)

        with autocast("cuda"):  # ✅ Correct AMP usage
            dist = agent(s)
            dist = dist[range(BATCH_SIZE), a]

            with torch.no_grad():
                next_dist = target_agent(s2)
                next_q = torch.sum(next_dist * agent.supports, dim=2)
                next_action = torch.argmax(next_q, dim=1)
                next_dist = next_dist[range(BATCH_SIZE), next_action]

                Tz = r.unsqueeze(1) + GAMMA * agent.supports.unsqueeze(0) * (1 - d.unsqueeze(1))
                Tz = Tz.clamp(agent.Vmin, agent.Vmax)

                b = (Tz - agent.Vmin) / ((agent.Vmax - agent.Vmin) / agent.num_atoms)
                l = b.floor().clamp(0, agent.num_atoms - 1).long()
                u = b.ceil().clamp(0, agent.num_atoms - 1).long()

                offset = torch.arange(BATCH_SIZE, device=device).unsqueeze(1) * agent.num_atoms
                l_idx = (l + offset).view(-1)
                u_idx = (u + offset).view(-1)

                proj_dist = torch.zeros(BATCH_SIZE * agent.num_atoms, device=device)
                next_dist = next_dist.view(-1)
                b = b.view(-1)
                l = l.view(-1)
                u = u.view(-1)

                proj_dist.index_add_(0, l_idx, next_dist * (u.float() - b))
                proj_dist.index_add_(0, u_idx, next_dist * (b - l.float()))
                m = proj_dist.view(BATCH_SIZE, agent.num_atoms)

            log_dist = torch.log(dist + 1e-6)
            loss_per_sample = -(m * log_dist).sum(1)
            loss = (loss_per_sample * weights).mean()

        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        agent.reset_noise()

        td_error = loss_per_sample.detach()
        buffer.update_priorities(idxs, td_error)

    if t % TARGET_UPDATE_FREQ == 0:
        target_agent.load_state_dict(agent.state_dict())

    if t % EVAL_EVERY == 0 and episode_count > 5:
        avg_reward = np.mean(episode_rewards[-10:])
        print(f"📊 Step {t}: Avg Last 10 Ep Reward = {avg_reward:.2f}")

    if t % LOG_FREQ == 0:
        print(f"🌀 Step {t}, Buffer size: {len(buffer)}")

# -------------------- Final Evaluation & Reporting --------------------

save_rewards_csv(REWARD_LOG_FILE)
plot_rewards("Rainbow DQN – Bowling-v5 Reward Curve", window=10)
estimate_convergence_verbose(episode_rewards, threshold=SUCCESS_THRESHOLD, window=10)
compute_success_rate(episode_rewards, threshold=SUCCESS_THRESHOLD)
evaluate_agent(agent, env, episodes=5, device=device)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 24
#      21 n_step_buffer = deque(maxlen=N_STEP)
#      22 n_gamma = GAMMA ** N_STEP
# ---> 24 state, _ = env.reset()
#      25 episode_reward = 0
#      26 episode_count = 0
#
# File ~/Documents/NOVA IMS/2 SEMESTER/Reinforcement Learning/RL24_25/Environment bowling/preprocessing.py:49, in ManualPreprocessWrapper.reset(self, **kwargs)
#      47 def reset(self, **kwargs):
#      48     obs, info = self.env.reset(**kwargs)
# ---> 49     processed = self._preprocess(obs)
#      50     for _ in range(self.frame_stack):
#      51         self.frames.append(processed)
#
# File ~/Documents/NOVA IMS/2 SEMESTER/Reinforcement Learning/RL24_25/Environment bowling/preprocessing.py:62, in ManualPreprocessWrapper._preprocess(self, obs)
#      60 def _preprocess(self, obs):
#      61     # Transform on GPU, return as uint8 NumPy array for compatibility
# ---> 62     tensor = self.transform(obs).to(self.device)  # shape: (1, 84, 84)
#      63     return (tensor * 255).byte().squeeze(0).cpu().numpy()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/cuda/__init__.py:293, in _lazy_init()
#     288     raise RuntimeError(
#     289         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     290         "multiprocessing, you must use the 'spawn' start method"
#     291     )
#     292 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 293     raise AssertionError("Torch not compiled with CUDA enabled")
#     294 if _cudart is None:
#     295     raise AssertionError(
#     296         "libcudart functions unavailable. It looks like you have a broken build?"
#     297     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
from torch.amp import autocast  # ✅ NEW AMP import
from torch.cuda.amp import GradScaler

# -------------------- CONFIGURATION --------------------
TOTAL_TIMESTEPS = 30_000
BATCH_SIZE = 64
LEARNING_RATE = 5e-5
EVAL_EVERY = 25_000
MAX_STEPS_PER_EPISODE = 1000
N_STEP = 3
GAMMA = 0.99
WARMUP_STEPS = 500
TARGET_UPDATE_FREQ = 20_000
LOG_FREQ = 5000
REWARD_LOG_FILE = "rainbow_bowling_rewards.csv"
SUCCESS_THRESHOLD = 5.0
# ------------------------------------------------------

# -------------------- SETUP --------------------
buffer = PrioritizedReplayBuffer()
n_step_buffer = deque(maxlen=N_STEP)
n_gamma = GAMMA ** N_STEP

state, _ = env.reset()
episode_reward = 0
episode_count = 0
episode_step_count = 0
best_reward = float('-inf')

optimizer = torch.optim.Adam(agent.parameters(), lr=LEARNING_RATE)
scaler = GradScaler()

for t in range(TOTAL_TIMESTEPS):
    if t < WARMUP_STEPS:
        action = env.action_space.sample()
    else:
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        action = agent.act(state_tensor)

    next_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    episode_step_count += 1
    done = done or (episode_step_count >= MAX_STEPS_PER_EPISODE)

    if reward != 0:
        print(f"🔥 Non-zero reward at step {t}: {reward}")

    n_step_buffer.append((state, action, reward, next_state, done))
    if len(n_step_buffer) == N_STEP:
        ns, na, nr, ns2, nd = compute_n_step_transition(n_step_buffer)
        buffer.add(ns, na, nr, ns2, nd)

    episode_reward, episode_count, state = track_reward(
        episode_reward, episode_count, reward, done, t, env, next_state
    )

    if done:
        episode_step_count = 0
        n_step_buffer.clear()

    # Training step
    if len(buffer) > BATCH_SIZE:
        s, a, r, s2, d, weights, idxs = buffer.sample(BATCH_SIZE)
        s = s.to(device)
        s2 = s2.to(device)
        a = a.to(device)
        r = r.to(device)
        d = d.to(device)
        weights = weights.to(device)

        with autocast("cuda"):  # ✅ Correct AMP usage
            dist = agent(s)
            dist = dist[range(BATCH_SIZE), a]

            with torch.no_grad():
                next_dist = target_agent(s2)
                next_q = torch.sum(next_dist * agent.supports, dim=2)
                next_action = torch.argmax(next_q, dim=1)
                next_dist = next_dist[range(BATCH_SIZE), next_action]

                Tz = r.unsqueeze(1) + GAMMA * agent.supports.unsqueeze(0) * (1 - d.unsqueeze(1))
                Tz = Tz.clamp(agent.Vmin, agent.Vmax)

                b = (Tz - agent.Vmin) / ((agent.Vmax - agent.Vmin) / agent.num_atoms)
                l = b.floor().clamp(0, agent.num_atoms - 1).long()
                u = b.ceil().clamp(0, agent.num_atoms - 1).long()

                offset = torch.arange(BATCH_SIZE, device=device).unsqueeze(1) * agent.num_atoms
                l_idx = (l + offset).view(-1)
                u_idx = (u + offset).view(-1)

                proj_dist = torch.zeros(BATCH_SIZE * agent.num_atoms, device=device)
                next_dist = next_dist.view(-1)
                b = b.view(-1)
                l = l.view(-1)
                u = u.view(-1)

                proj_dist.index_add_(0, l_idx, next_dist * (u.float() - b))
                proj_dist.index_add_(0, u_idx, next_dist * (b - l.float()))
                m = proj_dist.view(BATCH_SIZE, agent.num_atoms)

            log_dist = torch.log(dist + 1e-6)
            loss_per_sample = -(m * log_dist).sum(1)
            loss = (loss_per_sample * weights).mean()

        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        agent.reset_noise()

        td_error = loss_per_sample.detach()
        buffer.update_priorities(idxs, td_error)

    if t % TARGET_UPDATE_FREQ == 0:
        target_agent.load_state_dict(agent.state_dict())

    if t % EVAL_EVERY == 0 and episode_count > 5:
        avg_reward = np.mean(episode_rewards[-10:])
        print(f"📊 Step {t}: Avg Last 10 Ep Reward = {avg_reward:.2f}")

    if t % LOG_FREQ == 0:
        print(f"🌀 Step {t}, Buffer size: {len(buffer)}")

# -------------------- Final Evaluation & Reporting --------------------

save_rewards_csv(REWARD_LOG_FILE)
plot_rewards("Rainbow DQN – Bowling-v5 Reward Curve", window=10)
estimate_convergence_verbose(episode_rewards, threshold=SUCCESS_THRESHOLD, window=10)
compute_success_rate(episode_rewards, threshold=SUCCESS_THRESHOLD)
evaluate_agent(agent, env, episodes=5, device=device)
