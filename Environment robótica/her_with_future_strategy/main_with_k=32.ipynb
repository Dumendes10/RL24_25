# %%
import numpy as np
import gymnasium as gym
import panda_gym
import torch
import matplotlib.pyplot as plt
import os
import json
from utils import create_directory, print_env_info, save_training_data
from sac import SAC
from td3 import TD3
from random_search import run_random_search, generate_sac_params, generate_td3_params
from random_search import train_sac_with_params, train_td3_with_params, evaluate_policy
from IPython.display import clear_output, display
import warnings

warnings.filterwarnings('ignore')

# Set up directory structure
create_directory("./results")
create_directory("./results/random_search")
create_directory("./results/random_search/sac")
create_directory("./results/random_search/td3")
create_directory("./results/random_search_her")
create_directory("./results/random_search_her/sac")
create_directory("./results/random_search_her/td3")
# Out:
# Using device: cpu

# %%
# Define environment
ENV_NAME = "PandaReach-v3"

# Print environment information
env = gym.make(ENV_NAME)
print_env_info(env)
env.close()

def run_training(algorithm='both', use_her=False, her_strategy="future", k=4, n_trials=5, max_timesteps=30000):
    
    """
    Run random search and training for specified algorithms
    
    Args:
        algorithm: Algorithm to run ('sac', 'td3', 'both', 'sac_her', 'td3_her', 'both_her')
        use_her: Whether to use Hindsight Experience Replay
        n_trials: Number of trials for random search
        max_timesteps: Maximum timesteps per trial
        
    Returns:
        results: Dictionary with training results
    """
    # Determine which algorithms to run
    algorithms = []
    if algorithm == 'both':
        algorithms = ['sac', 'td3']
    elif algorithm == 'sac':
        algorithms = ['sac']
    elif algorithm == 'td3':
        algorithms = ['td3']
    elif algorithm == 'sac_her':
        algorithms = ['sac']
        use_her = True
    elif algorithm == 'td3_her':
        algorithms = ['td3']
        use_her = True
    elif algorithm == 'both_her':
        algorithms = ['sac', 'td3']
        use_her = True
    else:
        print(f"Invalid algorithm: {algorithm}")
        return None
    
    # Set up save directory based on whether HER is used
    save_dir = "./results/random_search_her" if use_her else "./results/random_search"
    
    # Run random search
    print("====================")
    print(f"Running random search for {', '.join(algorithms)}" + (" with HER" if use_her else ""))
    print("====================")
    
    results = run_random_search(
        n_trials=n_trials,
        max_timesteps=max_timesteps,
        save_dir=save_dir,
        use_her=use_her,
        her_strategy=her_strategy,
        her_k=k,
        algorithms=algorithms
    )
    
    # Load best parameters
    best_params_path = f"{save_dir}/best_params{'_her' if use_her else ''}.json"
    
    if os.path.exists(best_params_path):
        with open(best_params_path, 'r') as f:
            best_params = json.load(f)
            
        # Print best parameters
        for alg in algorithms:
            if alg in best_params:
                print(f"\n==== Best {alg.upper()}" + (" + HER" if use_her else "") + f" Parameters ====")
                print(f"Success Rate: {best_params[alg]['success_rate']}")
                for param, value in best_params[alg]['params'].items():
                    print(f"{param}: {value}")
    
    return results

def compare_algorithms(algorithms=['sac', 'td3', 'sac_her', 'td3_her'], 
                      her_strategy="future", k=4, n_trials=3, max_timesteps=30000):
    """
    Compare multiple algorithms by running them and plotting results
    
    Args:
        algorithms: List of algorithms to compare
        n_trials: Number of trials for random search
        max_timesteps: Maximum timesteps per trial
        
    Returns:
        comparison_results: Dictionary with best results for each algorithm
    """
    comparison_results = {}
    
    # Run each algorithm
    for alg in algorithms:
        print(f"\n==== Running {alg.upper()} ====")
        use_her = 'her' in alg
        base_alg = alg.replace('_her', '')
        
        # Run training
        results = run_training(
        algorithm=alg,
        use_her=use_her,
        her_strategy=her_strategy,
        k=k,
        n_trials=n_trials,
        max_timesteps=max_timesteps
        )
        
        # Store results
        if results:
            if base_alg == 'sac' and results.get('sac_results'):
                comparison_results[alg] = max(results['sac_results'], 
                                             key=lambda x: x['final_success_rate'])
            elif base_alg == 'td3' and results.get('td3_results'):
                comparison_results[alg] = max(results['td3_results'],
                                             key=lambda x: x['final_success_rate'])
            elif base_alg == 'both':
                if results.get('sac_results'):
                    comparison_results['sac' + ('_her' if use_her else '')] = max(
                        results['sac_results'], key=lambda x: x['final_success_rate'])
                if results.get('td3_results'):
                    comparison_results['td3' + ('_her' if use_her else '')] = max(
                        results['td3_results'], key=lambda x: x['final_success_rate'])
    
    # Plot comparison if we have results
    if comparison_results:
        plot_algorithm_comparison(comparison_results)
    
    return comparison_results
# Replace your current plot_algorithm_comparison function with this one
def plot_algorithm_comparison(comparison_results):
    """
    Plot comprehensive comparison of algorithm performance
    
    Args:
        comparison_results: Dictionary with best results for each algorithm
    """
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    
    # Line styles and colors for each algorithm
    styles = {
        'sac': {'color': 'blue', 'linestyle': '-', 'label': 'SAC'},
        'td3': {'color': 'orange', 'linestyle': '-', 'label': 'TD3'},
        'sac_her': {'color': 'green', 'linestyle': '-', 'label': 'SAC+HER'},
        'td3_her': {'color': 'red', 'linestyle': '-', 'label': 'TD3+HER'}
    }
    
    # Plot 1: Success rates over evaluations
    ax1 = axes[0, 0]
    for alg, result in comparison_results.items():
        if 'success_rates' in result and len(result['success_rates']) > 0:
            ax1.plot(range(len(result['success_rates'])), result['success_rates'], 
                     **styles[alg.lower()])
    ax1.set_xlabel('Evaluation Step')
    ax1.set_ylabel('Success Rate')
    ax1.set_title('Success Rate vs Evaluation Step')
    ax1.legend()
    ax1.grid(True)
    
    # Plot 2: Rewards over episodes
    ax2 = axes[0, 1]
    for alg, result in comparison_results.items():
        if 'rewards' in result and len(result['rewards']) > 0:
            # Smooth rewards if possible
            if len(result['rewards']) > 10:
                window_size = min(10, len(result['rewards']) // 5)
                weights = np.ones(window_size) / window_size
                smoothed = np.convolve(result['rewards'], weights, mode='valid')
                ax2.plot(range(len(smoothed)), smoothed, **styles[alg.lower()])
            else:
                ax2.plot(range(len(result['rewards'])), result['rewards'], **styles[alg.lower()])
    ax2.set_xlabel('Episode')
    ax2.set_ylabel('Average Reward')
    ax2.set_title('Episode Reward vs Episode')
    ax2.legend()
    ax2.grid(True)
    
    # Plot 3: Episode lengths over episodes
    ax3 = axes[0, 2]
    for alg, result in comparison_results.items():
        if 'episode_lengths' in result and len(result['episode_lengths']) > 0:
            # Smooth episode lengths if possible
            if len(result['episode_lengths']) > 10:
                window_size = min(10, len(result['episode_lengths']) // 5)
                weights = np.ones(window_size) / window_size
                smoothed = np.convolve(result['episode_lengths'], weights, mode='valid')
                ax3.plot(range(len(smoothed)), smoothed, **styles[alg.lower()])
            else:
                ax3.plot(range(len(result['episode_lengths'])), result['episode_lengths'], 
                         **styles[alg.lower()])
    ax3.set_xlabel('Episode')
    ax3.set_ylabel('Episode Length')
    ax3.set_title('Episode Length vs Episode')
    ax3.legend()
    ax3.grid(True)
    
    # Plot 4: Final success rates (bar chart)
    ax4 = axes[1, 0]
    algs = list(comparison_results.keys())
    success_rates = [result['final_success_rate'] for result in comparison_results.values()]
    colors = [styles[alg.lower()]['color'] for alg in algs]
    
    ax4.bar(algs, success_rates, color=colors)
    ax4.set_xlabel('Algorithm')
    ax4.set_ylabel('Final Success Rate')
    ax4.set_title('Final Success Rate Comparison')
    ax4.grid(True)
    
    # Plot 5: Training time / convergence speed
    ax5 = axes[1, 1]
    steps_to_converge = []
    for alg, result in comparison_results.items():
        if 'success_rates' in result and len(result['success_rates']) > 1:
            # Define convergence as reaching 90% of final success rate
            threshold = 0.9 * result['final_success_rate']
            for i, rate in enumerate(result['success_rates']):
                if rate >= threshold:
                    steps_to_converge.append(i)
                    break
            else:
                steps_to_converge.append(len(result['success_rates']))
        else:
            steps_to_converge.append(0)
    
    ax5.bar(algs, steps_to_converge, color=colors)
    ax5.set_xlabel('Algorithm')
    ax5.set_ylabel('Evaluations to Converge')
    ax5.set_title('Convergence Speed')
    ax5.grid(True)
    
    # Plot 6: Average episode length
    ax6 = axes[1, 2]
    avg_lengths = []
    for result in comparison_results.values():
        if 'episode_lengths' in result and len(result['episode_lengths']) > 0:
            # Average of last 10% of episodes
            cutoff = max(1, int(len(result['episode_lengths']) * 0.9))
            avg_lengths.append(np.mean(result['episode_lengths'][cutoff:]))
        else:
            avg_lengths.append(0)
    
    ax6.bar(algs, avg_lengths, color=colors)
    ax6.set_xlabel('Algorithm')
    ax6.set_ylabel('Avg Episode Length')
    ax6.set_title('Final Average Episode Length')
    ax6.grid(True)
    
    plt.tight_layout()
    plt.savefig('./results/comprehensive_comparison.png')
    plt.show()
# Out:
# ---------------------------------------
# Environment: PandaReach-v3
# Observation Space: Dict('achieved_goal': Box(-10.0, 10.0, (3,), float32), 'desired_goal': Box(-10.0, 10.0, (3,), float32), 'observation': Box(-10.0, 10.0, (6,), float32))
# Action Space: Box(-1.0, 1.0, (3,), float32)
# Action Space High: [1. 1. 1.]
# Action Space Low: [-1. -1. -1.]
# ---------------------------------------

# %%
# Execute this in Jupyter notebook
if __name__ == "__main__":
    # Run a single algorithm
    #results = run_training(algorithm='sac', n_trials=3, max_timesteps=30000)
    
    # Run with HER
    #results_her = run_training(algorithm='sac_her', n_trials=3, max_timesteps=30000)  
    
    # Compare algorithms with the "future" strategy (default)
    comparison = compare_algorithms(
        algorithms=['sac_her', 'td3_her'],
        her_strategy="future",  # Using future strategy
        k=32,                   # Sample 4 goals per transition
        n_trials=2,
        max_timesteps=30000
    )
# Out:
# ==== Running SAC_HER ====
# ====================
# Running random search for sac with HER
# ====================
# ---------------------------------------
# Environment: PandaReach-v3
# Observation Space: Dict('achieved_goal': Box(-10.0, 10.0, (3,), float32), 'desired_goal': Box(-10.0, 10.0, (3,), float32), 'observation': Box(-10.0, 10.0, (6,), float32))
# Action Space: Box(-1.0, 1.0, (3,), float32)
# Action Space High: [1. 1. 1.]
# Action Space Low: [-1. -1. -1.]
# ---------------------------------------
#
# ==== Running Random Search for SAC with HER ====
#
# SAC Trial 1/2
# Parameters: {'hidden_dim': 64, 'lr': 0.0005, 'gamma': 0.9293999096631801, 'tau': 0.02, 'alpha': 0.16036170650970208, 'automatic_entropy_tuning': True, 'batch_size': 32, 'buffer_size': 200000, 'learning_starts': 500}
# Episode 1: Total reward = -50.000, Length = 50
# Episode 2: Total reward = -50.000, Length = 50
# Episode 3: Total reward = -50.000, Length = 50
# Episode 4: Total reward = -50.000, Length = 50
# Episode 5: Total reward = -50.000, Length = 50
# Episode 6: Total reward = -50.000, Length = 50
# Episode 7: Total reward = -50.000, Length = 50
# Episode 8: Total reward = -50.000, Length = 50
# Episode 9: Total reward = -50.000, Length = 50
# Episode 10: Total reward = -50.000, Length = 50
# Episode 11: Total reward = -2.000, Length = 3
# Episode 12: Total reward = -50.000, Length = 50
# Episode 13: Total reward = -50.000, Length = 50
# Episode 14: Total reward = -50.000, Length = 50
# Episode 15: Total reward = -50.000, Length = 50
# Episode 16: Total reward = -50.000, Length = 50
# Episode 17: Total reward = -50.000, Length = 50
# Episode 18: Total reward = -50.000, Length = 50
# Episode 19: Total reward = -50.000, Length = 50
# Episode 20: Total reward = -50.000, Length = 50
# Episode 21: Total reward = -50.000, Length = 50
# Episode 22: Total reward = -50.000, Length = 50
# Episode 23: Total reward = -50.000, Length = 50
# Episode 24: Total reward = -50.000, Length = 50
# Episode 25: Total reward = -50.000, Length = 50
# Episode 26: Total reward = -50.000, Length = 50
# Episode 27: Total reward = -50.000, Length = 50
# Episode 28: Total reward = -50.000, Length = 50
# Episode 29: Total reward = -8.000, Length = 9
# Episode 30: Total reward = -50.000, Length = 50
# Episode 31: Total reward = -1.000, Length = 2
# Episode 32: Total reward = -10.000, Length = 11
# Episode 33: Total reward = -19.000, Length = 20
# Episode 34: Total reward = -50.000, Length = 50
# Episode 35: Total reward = -50.000, Length = 50
# Episode 36: Total reward = -30.000, Length = 31
# Episode 37: Total reward = -50.000, Length = 50
# Episode 38: Total reward = -2.000, Length = 3
# Episode 39: Total reward = -7.000, Length = 8
# Episode 40: Total reward = -50.000, Length = 50
# Episode 41: Total reward = -50.000, Length = 50
# Episode 42: Total reward = -6.000, Length = 7
# Episode 43: Total reward = -50.000, Length = 50
# Episode 44: Total reward = -50.000, Length = 50
# Episode 45: Total reward = -50.000, Length = 50
# Episode 46: Total reward = -50.000, Length = 50
# Episode 47: Total reward = -15.000, Length = 16
# Episode 48: Total reward = -4.000, Length = 5
# Episode 49: Total reward = -50.000, Length = 50
# Episode 50: Total reward = -50.000, Length = 50
# Episode 51: Total reward = -50.000, Length = 50
# Episode 52: Total reward = -50.000, Length = 50
# Episode 53: Total reward = -50.000, Length = 50
# Episode 54: Total reward = -50.000, Length = 50
# Episode 55: Total reward = -50.000, Length = 50
# Episode 56: Total reward = -50.000, Length = 50
# Episode 57: Total reward = -50.000, Length = 50
# Episode 58: Total reward = -50.000, Length = 50
# Episode 59: Total reward = -50.000, Length = 50
# Episode 60: Total reward = -50.000, Length = 50
# Episode 61: Total reward = -4.000, Length = 5
# Episode 62: Total reward = -50.000, Length = 50
# Episode 63: Total reward = -50.000, Length = 50
# Episode 64: Total reward = -50.000, Length = 50
# Episode 65: Total reward = -50.000, Length = 50
# Episode 66: Total reward = -50.000, Length = 50
# Episode 67: Total reward = -6.000, Length = 7
# Episode 68: Total reward = -50.000, Length = 50
# Episode 69: Total reward = -50.000, Length = 50
# Episode 70: Total reward = -50.000, Length = 50
# Episode 71: Total reward = -50.000, Length = 50
# Episode 72: Total reward = -50.000, Length = 50
# Episode 73: Total reward = -8.000, Length = 9
# Episode 74: Total reward = -50.000, Length = 50
# Episode 75: Total reward = -50.000, Length = 50
# Episode 76: Total reward = -50.000, Length = 50
# Episode 77: Total reward = -50.000, Length = 50
# Episode 78: Total reward = -50.000, Length = 50
# Episode 79: Total reward = -50.000, Length = 50
# Episode 80: Total reward = -50.000, Length = 50
# Episode 81: Total reward = -50.000, Length = 50
# Episode 82: Total reward = -50.000, Length = 50
# Episode 83: Total reward = -50.000, Length = 50
# Episode 84: Total reward = -50.000, Length = 50
# Episode 85: Total reward = -50.000, Length = 50
# Episode 86: Total reward = -50.000, Length = 50
# Episode 87: Total reward = -50.000, Length = 50
# Episode 88: Total reward = 0.000, Length = 1
# Episode 89: Total reward = -50.000, Length = 50
# Episode 90: Total reward = -50.000, Length = 50
# Episode 91: Total reward = -10.000, Length = 11
# Episode 92: Total reward = -50.000, Length = 50
# Episode 93: Total reward = -5.000, Length = 6
# Episode 94: Total reward = -50.000, Length = 50
# Episode 95: Total reward = -50.000, Length = 50
# Episode 96: Total reward = -50.000, Length = 50
# Episode 97: Total reward = -50.000, Length = 50
# Episode 98: Total reward = -6.000, Length = 7
# Episode 99: Total reward = -50.000, Length = 50
# Episode 100: Total reward = -50.000, Length = 50
# Episode 101: Total reward = -50.000, Length = 50
# Episode 102: Total reward = -50.000, Length = 50
# Episode 103: Total reward = -50.000, Length = 50
# Episode 104: Total reward = -50.000, Length = 50
# Episode 105: Total reward = -50.000, Length = 50
# Episode 106: Total reward = -50.000, Length = 50
# Episode 107: Total reward = -28.000, Length = 29
# Episode 108: Total reward = -4.000, Length = 5
# Episode 109: Total reward = -50.000, Length = 50
# Episode 110: Total reward = -50.000, Length = 50
# Episode 111: Total reward = -50.000, Length = 50
# Episode 112: Total reward = -18.000, Length = 19
# Episode 113: Total reward = -50.000, Length = 50
# Episode 114: Total reward = -50.000, Length = 50
# Episode 115: Total reward = -50.000, Length = 50
# Episode 116: Total reward = -50.000, Length = 50
#
# Timestep 5000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -45.400, Success rate: 0.100
# ---------------------------------------
# Episode 117: Total reward = -50.000, Length = 50
# Episode 118: Total reward = -50.000, Length = 50
# Episode 119: Total reward = -50.000, Length = 50
# Episode 120: Total reward = -50.000, Length = 50
# Episode 121: Total reward = -50.000, Length = 50
# Episode 122: Total reward = -50.000, Length = 50
# Episode 123: Total reward = -50.000, Length = 50
# Episode 124: Total reward = -50.000, Length = 50
# Episode 125: Total reward = -50.000, Length = 50
# Episode 126: Total reward = -2.000, Length = 3
# Episode 127: Total reward = -50.000, Length = 50
# Episode 128: Total reward = -50.000, Length = 50
# Episode 129: Total reward = -50.000, Length = 50
# Episode 130: Total reward = -50.000, Length = 50
# Episode 131: Total reward = -50.000, Length = 50
# Episode 132: Total reward = -50.000, Length = 50
# Episode 133: Total reward = -50.000, Length = 50
# Episode 134: Total reward = -50.000, Length = 50
# Episode 135: Total reward = -50.000, Length = 50
# Episode 136: Total reward = -50.000, Length = 50
# Episode 137: Total reward = -4.000, Length = 5
# Episode 138: Total reward = -50.000, Length = 50
# Episode 139: Total reward = -50.000, Length = 50
# Episode 140: Total reward = -3.000, Length = 4
# Episode 141: Total reward = -50.000, Length = 50
# Episode 142: Total reward = -3.000, Length = 4
# Episode 143: Total reward = -50.000, Length = 50
# Episode 144: Total reward = -50.000, Length = 50
# Episode 145: Total reward = -50.000, Length = 50
# Episode 146: Total reward = -50.000, Length = 50
# Episode 147: Total reward = -50.000, Length = 50
# Episode 148: Total reward = -50.000, Length = 50
# Episode 149: Total reward = -50.000, Length = 50
# Episode 150: Total reward = -50.000, Length = 50
# Episode 151: Total reward = -50.000, Length = 50
# Episode 152: Total reward = -50.000, Length = 50
# Episode 153: Total reward = -50.000, Length = 50
# Episode 154: Total reward = -50.000, Length = 50
# Episode 155: Total reward = -50.000, Length = 50
# Episode 156: Total reward = -50.000, Length = 50
# Episode 157: Total reward = -50.000, Length = 50
# Episode 158: Total reward = -3.000, Length = 4
# Episode 159: Total reward = -50.000, Length = 50
# Episode 160: Total reward = -50.000, Length = 50
# Episode 161: Total reward = -50.000, Length = 50
# Episode 162: Total reward = -50.000, Length = 50
# Episode 163: Total reward = -50.000, Length = 50
# Episode 164: Total reward = -50.000, Length = 50
# Episode 165: Total reward = -50.000, Length = 50
# Episode 166: Total reward = -50.000, Length = 50
# Episode 167: Total reward = -50.000, Length = 50
# Episode 168: Total reward = -50.000, Length = 50
# Episode 169: Total reward = -50.000, Length = 50
# Episode 170: Total reward = -50.000, Length = 50
# Episode 171: Total reward = -50.000, Length = 50
# Episode 172: Total reward = -50.000, Length = 50
# Episode 173: Total reward = 0.000, Length = 1
# Episode 174: Total reward = -50.000, Length = 50
# Episode 175: Total reward = -50.000, Length = 50
# Episode 176: Total reward = -50.000, Length = 50
# Episode 177: Total reward = -50.000, Length = 50
# Episode 178: Total reward = -50.000, Length = 50
# Episode 179: Total reward = -50.000, Length = 50
# Episode 180: Total reward = -50.000, Length = 50
# Episode 181: Total reward = -50.000, Length = 50
# Episode 182: Total reward = -50.000, Length = 50
# Episode 183: Total reward = -50.000, Length = 50
# Episode 184: Total reward = -50.000, Length = 50
# Episode 185: Total reward = -50.000, Length = 50
# Episode 186: Total reward = -50.000, Length = 50
# Episode 187: Total reward = -3.000, Length = 4
# Episode 188: Total reward = -50.000, Length = 50
# Episode 189: Total reward = -50.000, Length = 50
# Episode 190: Total reward = -50.000, Length = 50
# Episode 191: Total reward = -50.000, Length = 50
# Episode 192: Total reward = -50.000, Length = 50
# Episode 193: Total reward = -50.000, Length = 50
# Episode 194: Total reward = -50.000, Length = 50
# Episode 195: Total reward = -50.000, Length = 50
# Episode 196: Total reward = -50.000, Length = 50
# Episode 197: Total reward = -10.000, Length = 11
# Episode 198: Total reward = -50.000, Length = 50
# Episode 199: Total reward = -50.000, Length = 50
# Episode 200: Total reward = -50.000, Length = 50
# Episode 201: Total reward = -50.000, Length = 50
# Episode 202: Total reward = -50.000, Length = 50
# Episode 203: Total reward = -50.000, Length = 50
# Episode 204: Total reward = -50.000, Length = 50
# Episode 205: Total reward = -50.000, Length = 50
# Episode 206: Total reward = -50.000, Length = 50
# Episode 207: Total reward = -50.000, Length = 50
# Episode 208: Total reward = -50.000, Length = 50
# Episode 209: Total reward = -50.000, Length = 50
# Episode 210: Total reward = -50.000, Length = 50
# Episode 211: Total reward = -50.000, Length = 50
# Episode 212: Total reward = -50.000, Length = 50
# Episode 213: Total reward = -50.000, Length = 50
# Episode 214: Total reward = -50.000, Length = 50
# Episode 215: Total reward = -50.000, Length = 50
# Episode 216: Total reward = -50.000, Length = 50
# Episode 217: Total reward = -13.000, Length = 14
# Episode 218: Total reward = -50.000, Length = 50
# Episode 219: Total reward = -50.000, Length = 50
# Episode 220: Total reward = -50.000, Length = 50
# Episode 221: Total reward = -50.000, Length = 50
# Episode 222: Total reward = -50.000, Length = 50
# Episode 223: Total reward = -50.000, Length = 50
# Episode 224: Total reward = -3.000, Length = 4
# Episode 225: Total reward = -50.000, Length = 50
#
# Timestep 10000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -40.500, Success rate: 0.200
# ---------------------------------------
# Episode 226: Total reward = -50.000, Length = 50
# Episode 227: Total reward = -50.000, Length = 50
# Episode 228: Total reward = -50.000, Length = 50
# Episode 229: Total reward = -50.000, Length = 50
# Episode 230: Total reward = -2.000, Length = 3
# Episode 231: Total reward = -50.000, Length = 50
# Episode 232: Total reward = -50.000, Length = 50
# Episode 233: Total reward = -50.000, Length = 50
# Episode 234: Total reward = -50.000, Length = 50
# Episode 235: Total reward = -50.000, Length = 50
# Episode 236: Total reward = -50.000, Length = 50
# Episode 237: Total reward = -50.000, Length = 50
# Episode 238: Total reward = -50.000, Length = 50
# Episode 239: Total reward = -50.000, Length = 50
# Episode 240: Total reward = -50.000, Length = 50
# Episode 241: Total reward = -50.000, Length = 50
# Episode 242: Total reward = -50.000, Length = 50
# Episode 243: Total reward = -50.000, Length = 50
# Episode 244: Total reward = -50.000, Length = 50
# Episode 245: Total reward = -50.000, Length = 50
# Episode 246: Total reward = -50.000, Length = 50
# Episode 247: Total reward = -50.000, Length = 50
# Episode 248: Total reward = -50.000, Length = 50
# Episode 249: Total reward = -50.000, Length = 50
# Episode 250: Total reward = -50.000, Length = 50
# Episode 251: Total reward = -50.000, Length = 50
# Episode 252: Total reward = -50.000, Length = 50
# Episode 253: Total reward = -50.000, Length = 50
# Episode 254: Total reward = 0.000, Length = 1
# Episode 255: Total reward = -50.000, Length = 50
# Episode 256: Total reward = -50.000, Length = 50
# Episode 257: Total reward = -50.000, Length = 50
# Episode 258: Total reward = -50.000, Length = 50
# Episode 259: Total reward = -50.000, Length = 50
# Episode 260: Total reward = -50.000, Length = 50
# Episode 261: Total reward = -50.000, Length = 50
# Episode 262: Total reward = -50.000, Length = 50
# Episode 263: Total reward = -50.000, Length = 50
# Episode 264: Total reward = -50.000, Length = 50
# Episode 265: Total reward = -50.000, Length = 50
# Episode 266: Total reward = -50.000, Length = 50
# Episode 267: Total reward = -50.000, Length = 50
# Episode 268: Total reward = -50.000, Length = 50
# Episode 269: Total reward = -50.000, Length = 50
# Episode 270: Total reward = -50.000, Length = 50
# Episode 271: Total reward = -3.000, Length = 4
# Episode 272: Total reward = -50.000, Length = 50
# Episode 273: Total reward = -50.000, Length = 50
# Episode 274: Total reward = -50.000, Length = 50
# Episode 275: Total reward = -50.000, Length = 50
# Episode 276: Total reward = -50.000, Length = 50
# Episode 277: Total reward = -50.000, Length = 50
# Episode 278: Total reward = -50.000, Length = 50
# Episode 279: Total reward = -50.000, Length = 50
# Episode 280: Total reward = -50.000, Length = 50
# Episode 281: Total reward = -50.000, Length = 50
# Episode 282: Total reward = -50.000, Length = 50
# Episode 283: Total reward = -50.000, Length = 50
# Episode 284: Total reward = -50.000, Length = 50
# Episode 285: Total reward = -50.000, Length = 50
# Episode 286: Total reward = -1.000, Length = 2
# Episode 287: Total reward = -50.000, Length = 50
# Episode 288: Total reward = -50.000, Length = 50
# Episode 289: Total reward = -50.000, Length = 50
# Episode 290: Total reward = -50.000, Length = 50
# Episode 291: Total reward = -50.000, Length = 50
# Episode 292: Total reward = -50.000, Length = 50
# Episode 293: Total reward = -50.000, Length = 50
# Episode 294: Total reward = -50.000, Length = 50
# Episode 295: Total reward = -50.000, Length = 50
# Episode 296: Total reward = -1.000, Length = 2
# Episode 297: Total reward = -50.000, Length = 50
# Episode 298: Total reward = -1.000, Length = 2
# Episode 299: Total reward = -50.000, Length = 50
# Episode 300: Total reward = -50.000, Length = 50
# Episode 301: Total reward = -50.000, Length = 50
# Episode 302: Total reward = -50.000, Length = 50
# Episode 303: Total reward = -50.000, Length = 50
# Episode 304: Total reward = -50.000, Length = 50
# Episode 305: Total reward = -50.000, Length = 50
# Episode 306: Total reward = -50.000, Length = 50
# Episode 307: Total reward = 0.000, Length = 1
# Episode 308: Total reward = -50.000, Length = 50
# Episode 309: Total reward = -50.000, Length = 50
# Episode 310: Total reward = -50.000, Length = 50
# Episode 311: Total reward = -50.000, Length = 50
# Episode 312: Total reward = -50.000, Length = 50
# Episode 313: Total reward = -1.000, Length = 2
# Episode 314: Total reward = 0.000, Length = 1
# Episode 315: Total reward = -50.000, Length = 50
# Episode 316: Total reward = -50.000, Length = 50
# Episode 317: Total reward = -50.000, Length = 50
# Episode 318: Total reward = -50.000, Length = 50
# Episode 319: Total reward = -50.000, Length = 50
# Episode 320: Total reward = -50.000, Length = 50
# Episode 321: Total reward = -50.000, Length = 50
# Episode 322: Total reward = -50.000, Length = 50
# Episode 323: Total reward = -50.000, Length = 50
# Episode 324: Total reward = -50.000, Length = 50
# Episode 325: Total reward = -50.000, Length = 50
# Episode 326: Total reward = -50.000, Length = 50
# Episode 327: Total reward = -50.000, Length = 50
# Episode 328: Total reward = -2.000, Length = 3
# Episode 329: Total reward = -50.000, Length = 50
# Episode 330: Total reward = -50.000, Length = 50
# Episode 331: Total reward = -50.000, Length = 50
# Episode 332: Total reward = -50.000, Length = 50
# Episode 333: Total reward = -50.000, Length = 50
# Episode 334: Total reward = -1.000, Length = 2
# Episode 335: Total reward = -6.000, Length = 7
# Episode 336: Total reward = -50.000, Length = 50
# Episode 337: Total reward = -50.000, Length = 50
#
# Timestep 15000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -44.500, Success rate: 0.200
# ---------------------------------------
# Episode 338: Total reward = -50.000, Length = 50
# Episode 339: Total reward = -20.000, Length = 21
# Episode 340: Total reward = -50.000, Length = 50
# Episode 341: Total reward = -50.000, Length = 50
# Episode 342: Total reward = -50.000, Length = 50
# Episode 343: Total reward = 0.000, Length = 1
# Episode 344: Total reward = -50.000, Length = 50
# Episode 345: Total reward = -50.000, Length = 50
# Episode 346: Total reward = -50.000, Length = 50
# Episode 347: Total reward = 0.000, Length = 1
# Episode 348: Total reward = -1.000, Length = 2
# Episode 349: Total reward = -50.000, Length = 50
# Episode 350: Total reward = -50.000, Length = 50
# Episode 351: Total reward = -50.000, Length = 50
# Episode 352: Total reward = -50.000, Length = 50
# Episode 353: Total reward = -50.000, Length = 50
# Episode 354: Total reward = -50.000, Length = 50
# Episode 355: Total reward = -50.000, Length = 50
# Episode 356: Total reward = -50.000, Length = 50
# Episode 357: Total reward = -50.000, Length = 50
# Episode 358: Total reward = -50.000, Length = 50
# Episode 359: Total reward = 0.000, Length = 1
# Episode 360: Total reward = -50.000, Length = 50
# Episode 361: Total reward = -50.000, Length = 50
# Episode 362: Total reward = -50.000, Length = 50
# Episode 363: Total reward = -50.000, Length = 50
# Episode 364: Total reward = -50.000, Length = 50
# Episode 365: Total reward = -50.000, Length = 50
# Episode 366: Total reward = -50.000, Length = 50
# Episode 367: Total reward = -50.000, Length = 50
# Episode 368: Total reward = -50.000, Length = 50
# Episode 369: Total reward = -50.000, Length = 50
# Episode 370: Total reward = -50.000, Length = 50
# Episode 371: Total reward = -50.000, Length = 50
# Episode 372: Total reward = -50.000, Length = 50
# Episode 373: Total reward = -50.000, Length = 50
# Episode 374: Total reward = -50.000, Length = 50
# Episode 375: Total reward = -50.000, Length = 50
# Episode 376: Total reward = -19.000, Length = 20
# Episode 377: Total reward = -50.000, Length = 50
# Episode 378: Total reward = -50.000, Length = 50
# Episode 379: Total reward = -50.000, Length = 50
# Episode 380: Total reward = -50.000, Length = 50
# Episode 381: Total reward = -50.000, Length = 50
# Episode 382: Total reward = -50.000, Length = 50
# Episode 383: Total reward = -50.000, Length = 50
# Episode 384: Total reward = -50.000, Length = 50
# Episode 385: Total reward = -50.000, Length = 50
# Episode 386: Total reward = -50.000, Length = 50
# Episode 387: Total reward = -50.000, Length = 50
# Episode 388: Total reward = -50.000, Length = 50
# Episode 389: Total reward = -2.000, Length = 3
# Episode 390: Total reward = -50.000, Length = 50
# Episode 391: Total reward = -50.000, Length = 50
# Episode 392: Total reward = -50.000, Length = 50
# Episode 393: Total reward = -50.000, Length = 50
# Episode 394: Total reward = -50.000, Length = 50
# Episode 395: Total reward = -50.000, Length = 50
# Episode 396: Total reward = -50.000, Length = 50
# Episode 397: Total reward = -50.000, Length = 50
# Episode 398: Total reward = -50.000, Length = 50
# Episode 399: Total reward = -50.000, Length = 50
# Episode 400: Total reward = -50.000, Length = 50
# Episode 401: Total reward = -50.000, Length = 50
# Episode 402: Total reward = -1.000, Length = 2
# Episode 403: Total reward = -50.000, Length = 50
# Episode 404: Total reward = -50.000, Length = 50
# Episode 405: Total reward = -50.000, Length = 50
# Episode 406: Total reward = -50.000, Length = 50
# Episode 407: Total reward = -50.000, Length = 50
# Episode 408: Total reward = -50.000, Length = 50
# Episode 409: Total reward = -50.000, Length = 50
# Episode 410: Total reward = -50.000, Length = 50
# Episode 411: Total reward = -50.000, Length = 50
# Episode 412: Total reward = -50.000, Length = 50
# Episode 413: Total reward = -1.000, Length = 2
# Episode 414: Total reward = -50.000, Length = 50
# Episode 415: Total reward = -50.000, Length = 50
# Episode 416: Total reward = -50.000, Length = 50
# Episode 417: Total reward = -4.000, Length = 5
# Episode 418: Total reward = -50.000, Length = 50
# Episode 419: Total reward = -50.000, Length = 50
# Episode 420: Total reward = -50.000, Length = 50
# Episode 421: Total reward = -50.000, Length = 50
# Episode 422: Total reward = -50.000, Length = 50
# Episode 423: Total reward = -50.000, Length = 50
# Episode 424: Total reward = -50.000, Length = 50
# Episode 425: Total reward = -50.000, Length = 50
# Episode 426: Total reward = -1.000, Length = 2
# Episode 427: Total reward = -50.000, Length = 50
# Episode 428: Total reward = -50.000, Length = 50
# Episode 429: Total reward = -50.000, Length = 50
# Episode 430: Total reward = -50.000, Length = 50
# Episode 431: Total reward = -50.000, Length = 50
# Episode 432: Total reward = -50.000, Length = 50
# Episode 433: Total reward = -50.000, Length = 50
# Episode 434: Total reward = -50.000, Length = 50
# Episode 435: Total reward = -50.000, Length = 50
# Episode 436: Total reward = -50.000, Length = 50
# Episode 437: Total reward = -50.000, Length = 50
# Episode 438: Total reward = -50.000, Length = 50
# Episode 439: Total reward = -50.000, Length = 50
# Episode 440: Total reward = -50.000, Length = 50
# Episode 441: Total reward = -50.000, Length = 50
# Episode 442: Total reward = -50.000, Length = 50
# Episode 443: Total reward = -50.000, Length = 50
# Episode 444: Total reward = -50.000, Length = 50
# Episode 445: Total reward = -50.000, Length = 50
# Episode 446: Total reward = -50.000, Length = 50
#
# Timestep 20000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -40.200, Success rate: 0.200
# ---------------------------------------
# Episode 447: Total reward = -50.000, Length = 50
# Episode 448: Total reward = -50.000, Length = 50
# Episode 449: Total reward = -50.000, Length = 50
# Episode 450: Total reward = -50.000, Length = 50
# Episode 451: Total reward = -50.000, Length = 50
# Episode 452: Total reward = -50.000, Length = 50
# Episode 453: Total reward = -2.000, Length = 3
# Episode 454: Total reward = -50.000, Length = 50
# Episode 455: Total reward = 0.000, Length = 1
# Episode 456: Total reward = -50.000, Length = 50
# Episode 457: Total reward = -50.000, Length = 50
# Episode 458: Total reward = -50.000, Length = 50
# Episode 459: Total reward = -50.000, Length = 50
# Episode 460: Total reward = -50.000, Length = 50
# Episode 461: Total reward = -50.000, Length = 50
# Episode 462: Total reward = -50.000, Length = 50
# Episode 463: Total reward = -50.000, Length = 50
# Episode 464: Total reward = -50.000, Length = 50
# Episode 465: Total reward = -50.000, Length = 50
# Episode 466: Total reward = -50.000, Length = 50
# Episode 467: Total reward = -50.000, Length = 50
# Episode 468: Total reward = -50.000, Length = 50
# Episode 469: Total reward = -50.000, Length = 50
# Episode 470: Total reward = -50.000, Length = 50
# Episode 471: Total reward = 0.000, Length = 1
# Episode 472: Total reward = -50.000, Length = 50
# Episode 473: Total reward = -50.000, Length = 50
# Episode 474: Total reward = -50.000, Length = 50
# Episode 475: Total reward = -50.000, Length = 50
# Episode 476: Total reward = -50.000, Length = 50
# Episode 477: Total reward = -50.000, Length = 50
# Episode 478: Total reward = -50.000, Length = 50
# Episode 479: Total reward = -50.000, Length = 50
# Episode 480: Total reward = -50.000, Length = 50
# Episode 481: Total reward = -50.000, Length = 50
# Episode 482: Total reward = -50.000, Length = 50
# Episode 483: Total reward = -50.000, Length = 50
# Episode 484: Total reward = -14.000, Length = 15
# Episode 485: Total reward = -50.000, Length = 50
# Episode 486: Total reward = -50.000, Length = 50
# Episode 487: Total reward = -50.000, Length = 50
# Episode 488: Total reward = -50.000, Length = 50
# Episode 489: Total reward = -50.000, Length = 50
# Episode 490: Total reward = -50.000, Length = 50
# Episode 491: Total reward = -50.000, Length = 50
# Episode 492: Total reward = -50.000, Length = 50
# Episode 493: Total reward = -50.000, Length = 50
# Episode 494: Total reward = -50.000, Length = 50
# Episode 495: Total reward = -50.000, Length = 50
# Episode 496: Total reward = -50.000, Length = 50
# Episode 497: Total reward = -50.000, Length = 50
# Episode 498: Total reward = -50.000, Length = 50
# Episode 499: Total reward = -50.000, Length = 50
# Episode 500: Total reward = -50.000, Length = 50
# Episode 501: Total reward = -50.000, Length = 50
# Episode 502: Total reward = -50.000, Length = 50
# Episode 503: Total reward = -50.000, Length = 50
# Episode 504: Total reward = -50.000, Length = 50
# Episode 505: Total reward = -50.000, Length = 50
# Episode 506: Total reward = -50.000, Length = 50
# Episode 507: Total reward = -50.000, Length = 50
# Episode 508: Total reward = 0.000, Length = 1
# Episode 509: Total reward = -50.000, Length = 50
# Episode 510: Total reward = -50.000, Length = 50
# Episode 511: Total reward = -50.000, Length = 50
# Episode 512: Total reward = -50.000, Length = 50
# Episode 513: Total reward = -50.000, Length = 50
# Episode 514: Total reward = -50.000, Length = 50
# Episode 515: Total reward = -50.000, Length = 50
# Episode 516: Total reward = -50.000, Length = 50
# Episode 517: Total reward = -50.000, Length = 50
# Episode 518: Total reward = -50.000, Length = 50
# Episode 519: Total reward = -50.000, Length = 50
# Episode 520: Total reward = -50.000, Length = 50
# Episode 521: Total reward = -50.000, Length = 50
# Episode 522: Total reward = -50.000, Length = 50
# Episode 523: Total reward = -50.000, Length = 50
# Episode 524: Total reward = -50.000, Length = 50
# Episode 525: Total reward = -50.000, Length = 50
# Episode 526: Total reward = -50.000, Length = 50
# Episode 527: Total reward = -50.000, Length = 50
# Episode 528: Total reward = -1.000, Length = 2
# Episode 529: Total reward = -50.000, Length = 50
# Episode 530: Total reward = -50.000, Length = 50
# Episode 531: Total reward = -50.000, Length = 50
# Episode 532: Total reward = -50.000, Length = 50
# Episode 533: Total reward = -50.000, Length = 50
# Episode 534: Total reward = -50.000, Length = 50
# Episode 535: Total reward = -50.000, Length = 50
# Episode 536: Total reward = -50.000, Length = 50
# Episode 537: Total reward = -50.000, Length = 50
# Episode 538: Total reward = -50.000, Length = 50
# Episode 539: Total reward = -50.000, Length = 50
# Episode 540: Total reward = -50.000, Length = 50
# Episode 541: Total reward = -50.000, Length = 50
# Episode 542: Total reward = -50.000, Length = 50
# Episode 543: Total reward = -50.000, Length = 50
# Episode 544: Total reward = -50.000, Length = 50
# Episode 545: Total reward = -50.000, Length = 50
# Episode 546: Total reward = -50.000, Length = 50
# Episode 547: Total reward = -50.000, Length = 50
# Episode 548: Total reward = -50.000, Length = 50
# Episode 549: Total reward = -50.000, Length = 50
# Episode 550: Total reward = -50.000, Length = 50
# Episode 551: Total reward = -50.000, Length = 50
# Episode 552: Total reward = -50.000, Length = 50
#
# Timestep 25000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -45.000, Success rate: 0.100
# ---------------------------------------
# Episode 553: Total reward = -50.000, Length = 50
# Episode 554: Total reward = -2.000, Length = 3
# Episode 555: Total reward = -50.000, Length = 50
# Episode 556: Total reward = -1.000, Length = 2
# Episode 557: Total reward = -50.000, Length = 50
# Episode 558: Total reward = -50.000, Length = 50
# Episode 559: Total reward = -50.000, Length = 50
# Episode 560: Total reward = -50.000, Length = 50
# Episode 561: Total reward = 0.000, Length = 1
# Episode 562: Total reward = -50.000, Length = 50
# Episode 563: Total reward = 0.000, Length = 1
# Episode 564: Total reward = -50.000, Length = 50
# Episode 565: Total reward = -50.000, Length = 50
# Episode 566: Total reward = -50.000, Length = 50
# Episode 567: Total reward = -50.000, Length = 50
# Episode 568: Total reward = -50.000, Length = 50
# Episode 569: Total reward = -50.000, Length = 50
# Episode 570: Total reward = -50.000, Length = 50
# Episode 571: Total reward = -50.000, Length = 50
# Episode 572: Total reward = -50.000, Length = 50
# Episode 573: Total reward = -50.000, Length = 50
# Episode 574: Total reward = -50.000, Length = 50
# Episode 575: Total reward = -50.000, Length = 50
# Episode 576: Total reward = -50.000, Length = 50
# Episode 577: Total reward = -50.000, Length = 50
# Episode 578: Total reward = -50.000, Length = 50
# Episode 579: Total reward = -50.000, Length = 50
# Episode 580: Total reward = -50.000, Length = 50
# Episode 581: Total reward = -50.000, Length = 50
# Episode 582: Total reward = -50.000, Length = 50
# Episode 583: Total reward = 0.000, Length = 1
# Episode 584: Total reward = -37.000, Length = 38
# Episode 585: Total reward = -50.000, Length = 50
# Episode 586: Total reward = -50.000, Length = 50
# Episode 587: Total reward = -50.000, Length = 50
# Episode 588: Total reward = -50.000, Length = 50
# Episode 589: Total reward = -50.000, Length = 50
# Episode 590: Total reward = -50.000, Length = 50
# Episode 591: Total reward = -50.000, Length = 50
# Episode 592: Total reward = -50.000, Length = 50
# Episode 593: Total reward = -50.000, Length = 50
# Episode 594: Total reward = -50.000, Length = 50
# Episode 595: Total reward = -50.000, Length = 50
# Episode 596: Total reward = -50.000, Length = 50
# Episode 597: Total reward = -50.000, Length = 50
# Episode 598: Total reward = -50.000, Length = 50
# Episode 599: Total reward = -50.000, Length = 50
# Episode 600: Total reward = -50.000, Length = 50
# Episode 601: Total reward = -50.000, Length = 50
# Episode 602: Total reward = -50.000, Length = 50
# Episode 603: Total reward = -50.000, Length = 50
# Episode 604: Total reward = -50.000, Length = 50
# Episode 605: Total reward = -50.000, Length = 50
# Episode 606: Total reward = -50.000, Length = 50
# Episode 607: Total reward = -50.000, Length = 50
# Episode 608: Total reward = -50.000, Length = 50
# Episode 609: Total reward = -50.000, Length = 50
# Episode 610: Total reward = -50.000, Length = 50
# Episode 611: Total reward = -50.000, Length = 50
# Episode 612: Total reward = -50.000, Length = 50
# Episode 613: Total reward = -50.000, Length = 50
# Episode 614: Total reward = -50.000, Length = 50
# Episode 615: Total reward = -50.000, Length = 50
# Episode 616: Total reward = -50.000, Length = 50
# Episode 617: Total reward = -50.000, Length = 50
# Episode 618: Total reward = -50.000, Length = 50
# Episode 619: Total reward = -50.000, Length = 50
# Episode 620: Total reward = -50.000, Length = 50
# Episode 621: Total reward = -34.000, Length = 35
# Episode 622: Total reward = -50.000, Length = 50
# Episode 623: Total reward = -3.000, Length = 4
# Episode 624: Total reward = -50.000, Length = 50
# Episode 625: Total reward = -50.000, Length = 50
# Episode 626: Total reward = -50.000, Length = 50
# Episode 627: Total reward = -50.000, Length = 50
# Episode 628: Total reward = -50.000, Length = 50
# Episode 629: Total reward = -50.000, Length = 50
# Episode 630: Total reward = -50.000, Length = 50
# Episode 631: Total reward = -50.000, Length = 50
# Episode 632: Total reward = -50.000, Length = 50
# Episode 633: Total reward = -50.000, Length = 50
# Episode 634: Total reward = -50.000, Length = 50
# Episode 635: Total reward = -50.000, Length = 50
# Episode 636: Total reward = -50.000, Length = 50
# Episode 637: Total reward = -50.000, Length = 50
# Episode 638: Total reward = -50.000, Length = 50
# Episode 639: Total reward = -50.000, Length = 50
# Episode 640: Total reward = -50.000, Length = 50
# Episode 641: Total reward = -50.000, Length = 50
# Episode 642: Total reward = -50.000, Length = 50
# Episode 643: Total reward = -50.000, Length = 50
# Episode 644: Total reward = -50.000, Length = 50
# Episode 645: Total reward = -50.000, Length = 50
# Episode 646: Total reward = -50.000, Length = 50
# Episode 647: Total reward = -50.000, Length = 50
# Episode 648: Total reward = -50.000, Length = 50
# Episode 649: Total reward = -50.000, Length = 50
# Episode 650: Total reward = -50.000, Length = 50
# Episode 651: Total reward = -50.000, Length = 50
# Episode 652: Total reward = -50.000, Length = 50
# Episode 653: Total reward = -50.000, Length = 50
# Episode 654: Total reward = -50.000, Length = 50
# Episode 655: Total reward = -50.000, Length = 50
# Episode 656: Total reward = -3.000, Length = 4
# Episode 657: Total reward = -50.000, Length = 50
# Episode 658: Total reward = -50.000, Length = 50
# Episode 659: Total reward = -50.000, Length = 50
#
# Timestep 30000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -44.500, Success rate: 0.200
# ---------------------------------------
# Trial completed. Final success rate: 0.200
#
# SAC Trial 2/2
# Parameters: {'hidden_dim': 256, 'lr': 0.002, 'gamma': 0.9690812964797632, 'tau': 0.02, 'alpha': 0.08677390325123066, 'automatic_entropy_tuning': True, 'batch_size': 32, 'buffer_size': 100000, 'learning_starts': 1000}
# Episode 1: Total reward = -50.000, Length = 50
# Episode 2: Total reward = -50.000, Length = 50
# Episode 3: Total reward = -24.000, Length = 25
# Episode 4: Total reward = -50.000, Length = 50
# Episode 5: Total reward = -50.000, Length = 50
# Episode 6: Total reward = -50.000, Length = 50
# Episode 7: Total reward = -50.000, Length = 50
# Episode 8: Total reward = -50.000, Length = 50
# Episode 9: Total reward = -50.000, Length = 50
# Episode 10: Total reward = -50.000, Length = 50
# Episode 11: Total reward = -50.000, Length = 50
# Episode 12: Total reward = -50.000, Length = 50
# Episode 13: Total reward = -21.000, Length = 22
# Episode 14: Total reward = -50.000, Length = 50
# Episode 15: Total reward = -50.000, Length = 50
# Episode 16: Total reward = -50.000, Length = 50
# Episode 17: Total reward = -9.000, Length = 10
# Episode 18: Total reward = -50.000, Length = 50
# Episode 19: Total reward = -50.000, Length = 50
# Episode 20: Total reward = -50.000, Length = 50
# Episode 21: Total reward = -50.000, Length = 50
# Episode 22: Total reward = -50.000, Length = 50
# Episode 23: Total reward = -50.000, Length = 50
# Episode 24: Total reward = -50.000, Length = 50
# Episode 25: Total reward = -31.000, Length = 32
# Episode 26: Total reward = -50.000, Length = 50
# Episode 27: Total reward = -50.000, Length = 50
# Episode 28: Total reward = -50.000, Length = 50
# Episode 29: Total reward = -50.000, Length = 50
# Episode 30: Total reward = -50.000, Length = 50
# Episode 31: Total reward = -50.000, Length = 50
# Episode 32: Total reward = -28.000, Length = 29
# Episode 33: Total reward = -50.000, Length = 50
# Episode 34: Total reward = -24.000, Length = 25
# Episode 35: Total reward = -50.000, Length = 50
# Episode 36: Total reward = -4.000, Length = 5
# Episode 37: Total reward = -50.000, Length = 50
# Episode 38: Total reward = -50.000, Length = 50
# Episode 39: Total reward = -50.000, Length = 50
# Episode 40: Total reward = -36.000, Length = 37
# Episode 41: Total reward = -50.000, Length = 50
# Episode 42: Total reward = -50.000, Length = 50
# Episode 43: Total reward = -50.000, Length = 50
# Episode 44: Total reward = -50.000, Length = 50
# Episode 45: Total reward = -50.000, Length = 50
# Episode 46: Total reward = -50.000, Length = 50
# Episode 47: Total reward = -50.000, Length = 50
# Episode 48: Total reward = -50.000, Length = 50
# Episode 49: Total reward = -50.000, Length = 50
# Episode 50: Total reward = -50.000, Length = 50
# Episode 51: Total reward = -50.000, Length = 50
# Episode 52: Total reward = -50.000, Length = 50
# Episode 53: Total reward = -50.000, Length = 50
# Episode 54: Total reward = -50.000, Length = 50
# Episode 55: Total reward = -50.000, Length = 50
# Episode 56: Total reward = -50.000, Length = 50
# Episode 57: Total reward = -50.000, Length = 50
# Episode 58: Total reward = -50.000, Length = 50
# Episode 59: Total reward = -50.000, Length = 50
# Episode 60: Total reward = 0.000, Length = 1
# Episode 61: Total reward = -50.000, Length = 50
# Episode 62: Total reward = -50.000, Length = 50
# Episode 63: Total reward = -50.000, Length = 50
# Episode 64: Total reward = -50.000, Length = 50
# Episode 65: Total reward = -50.000, Length = 50
# Episode 66: Total reward = -50.000, Length = 50
# Episode 67: Total reward = -50.000, Length = 50
# Episode 68: Total reward = -50.000, Length = 50
# Episode 69: Total reward = -50.000, Length = 50
# Episode 70: Total reward = -50.000, Length = 50
# Episode 71: Total reward = -50.000, Length = 50
# Episode 72: Total reward = -50.000, Length = 50
# Episode 73: Total reward = -50.000, Length = 50
# Episode 74: Total reward = -50.000, Length = 50
# Episode 75: Total reward = -3.000, Length = 4
# Episode 76: Total reward = -50.000, Length = 50
# Episode 77: Total reward = -50.000, Length = 50
# Episode 78: Total reward = -50.000, Length = 50
# Episode 79: Total reward = -50.000, Length = 50
# Episode 80: Total reward = -50.000, Length = 50
# Episode 81: Total reward = -50.000, Length = 50
# Episode 82: Total reward = -3.000, Length = 4
# Episode 83: Total reward = -50.000, Length = 50
# Episode 84: Total reward = -50.000, Length = 50
# Episode 85: Total reward = -50.000, Length = 50
# Episode 86: Total reward = -50.000, Length = 50
# Episode 87: Total reward = -50.000, Length = 50
# Episode 88: Total reward = -50.000, Length = 50
# Episode 89: Total reward = -50.000, Length = 50
# Episode 90: Total reward = -50.000, Length = 50
# Episode 91: Total reward = -50.000, Length = 50
# Episode 92: Total reward = -50.000, Length = 50
# Episode 93: Total reward = -50.000, Length = 50
# Episode 94: Total reward = -50.000, Length = 50
# Episode 95: Total reward = -50.000, Length = 50
# Episode 96: Total reward = -50.000, Length = 50
# Episode 97: Total reward = -50.000, Length = 50
# Episode 98: Total reward = -50.000, Length = 50
# Episode 99: Total reward = -50.000, Length = 50
# Episode 100: Total reward = -50.000, Length = 50
# Episode 101: Total reward = 0.000, Length = 1
# Episode 102: Total reward = -24.000, Length = 25
# Episode 103: Total reward = -50.000, Length = 50
# Episode 104: Total reward = -50.000, Length = 50
# Episode 105: Total reward = -50.000, Length = 50
# Episode 106: Total reward = -50.000, Length = 50
# Episode 107: Total reward = -50.000, Length = 50
# Episode 108: Total reward = -50.000, Length = 50
#
# Timestep 5000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -50.000, Success rate: 0.000
# ---------------------------------------
# Episode 109: Total reward = -50.000, Length = 50
# Episode 110: Total reward = -50.000, Length = 50
# Episode 111: Total reward = -50.000, Length = 50
# Episode 112: Total reward = -50.000, Length = 50
# Episode 113: Total reward = -50.000, Length = 50
# Episode 114: Total reward = -50.000, Length = 50
# Episode 115: Total reward = -2.000, Length = 3
# Episode 116: Total reward = -50.000, Length = 50
# Episode 117: Total reward = -50.000, Length = 50
# Episode 118: Total reward = -50.000, Length = 50
# Episode 119: Total reward = -50.000, Length = 50
# Episode 120: Total reward = -50.000, Length = 50
# Episode 121: Total reward = -50.000, Length = 50
# Episode 122: Total reward = -50.000, Length = 50
# Episode 123: Total reward = -50.000, Length = 50
# Episode 124: Total reward = -50.000, Length = 50
# Episode 125: Total reward = -50.000, Length = 50
# Episode 126: Total reward = -50.000, Length = 50
# Episode 127: Total reward = -50.000, Length = 50
# Episode 128: Total reward = -50.000, Length = 50
# Episode 129: Total reward = -9.000, Length = 10
# Episode 130: Total reward = -50.000, Length = 50
# Episode 131: Total reward = -50.000, Length = 50
# Episode 132: Total reward = -50.000, Length = 50
# Episode 133: Total reward = -50.000, Length = 50
# Episode 134: Total reward = -50.000, Length = 50
# Episode 135: Total reward = -50.000, Length = 50
# Episode 136: Total reward = -50.000, Length = 50
# Episode 137: Total reward = -50.000, Length = 50
# Episode 138: Total reward = -50.000, Length = 50
# Episode 139: Total reward = -50.000, Length = 50
# Episode 140: Total reward = -50.000, Length = 50
# Episode 141: Total reward = -50.000, Length = 50
# Episode 142: Total reward = -50.000, Length = 50
# Episode 143: Total reward = -50.000, Length = 50
# Episode 144: Total reward = -50.000, Length = 50
# Episode 145: Total reward = -50.000, Length = 50
# Episode 146: Total reward = -50.000, Length = 50
# Episode 147: Total reward = -50.000, Length = 50
# Episode 148: Total reward = -50.000, Length = 50
# Episode 149: Total reward = -50.000, Length = 50
# Episode 150: Total reward = -50.000, Length = 50
# Episode 151: Total reward = -50.000, Length = 50
# Episode 152: Total reward = -50.000, Length = 50
# Episode 153: Total reward = -50.000, Length = 50
# Episode 154: Total reward = -50.000, Length = 50
# Episode 155: Total reward = -50.000, Length = 50
# Episode 156: Total reward = -50.000, Length = 50
# Episode 157: Total reward = -50.000, Length = 50
# Episode 158: Total reward = -50.000, Length = 50
# Episode 159: Total reward = -50.000, Length = 50
# Episode 160: Total reward = 0.000, Length = 1
# Episode 161: Total reward = -1.000, Length = 2
# Episode 162: Total reward = -50.000, Length = 50
# Episode 163: Total reward = -50.000, Length = 50
# Episode 164: Total reward = -50.000, Length = 50
# Episode 165: Total reward = -50.000, Length = 50
# Episode 166: Total reward = -50.000, Length = 50
# Episode 167: Total reward = -50.000, Length = 50
# Episode 168: Total reward = -50.000, Length = 50
# Episode 169: Total reward = -50.000, Length = 50
# Episode 170: Total reward = -50.000, Length = 50
# Episode 171: Total reward = -50.000, Length = 50
# Episode 172: Total reward = -50.000, Length = 50
# Episode 173: Total reward = -50.000, Length = 50
# Episode 174: Total reward = -50.000, Length = 50
# Episode 175: Total reward = -50.000, Length = 50
# Episode 176: Total reward = -50.000, Length = 50
# Episode 177: Total reward = -50.000, Length = 50
# Episode 178: Total reward = -50.000, Length = 50
# Episode 179: Total reward = -50.000, Length = 50
# Episode 180: Total reward = -50.000, Length = 50
# Episode 181: Total reward = -50.000, Length = 50
# Episode 182: Total reward = -50.000, Length = 50
# Episode 183: Total reward = -50.000, Length = 50
# Episode 184: Total reward = -50.000, Length = 50
# Episode 185: Total reward = -50.000, Length = 50
# Episode 186: Total reward = -50.000, Length = 50
# Episode 187: Total reward = -50.000, Length = 50
# Episode 188: Total reward = -50.000, Length = 50
# Episode 189: Total reward = -50.000, Length = 50
# Episode 190: Total reward = -50.000, Length = 50
# Episode 191: Total reward = -50.000, Length = 50
# Episode 192: Total reward = -50.000, Length = 50
# Episode 193: Total reward = -50.000, Length = 50
# Episode 194: Total reward = -50.000, Length = 50
# Episode 195: Total reward = -3.000, Length = 4
# Episode 196: Total reward = -50.000, Length = 50
# Episode 197: Total reward = -50.000, Length = 50
# Episode 198: Total reward = -50.000, Length = 50
# Episode 199: Total reward = -50.000, Length = 50
# Episode 200: Total reward = -50.000, Length = 50
# Episode 201: Total reward = -50.000, Length = 50
# Episode 202: Total reward = -50.000, Length = 50
# Episode 203: Total reward = -50.000, Length = 50
# Episode 204: Total reward = -50.000, Length = 50
# Episode 205: Total reward = 0.000, Length = 1
# Episode 206: Total reward = -50.000, Length = 50
# Episode 207: Total reward = -50.000, Length = 50
# Episode 208: Total reward = -50.000, Length = 50
# Episode 209: Total reward = -50.000, Length = 50
# Episode 210: Total reward = -50.000, Length = 50
# Episode 211: Total reward = -50.000, Length = 50
# Episode 212: Total reward = -3.000, Length = 4
# Episode 213: Total reward = -50.000, Length = 50
# Episode 214: Total reward = -50.000, Length = 50
# Episode 215: Total reward = -50.000, Length = 50
#
# Timestep 10000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -45.000, Success rate: 0.100
# ---------------------------------------
# Episode 216: Total reward = -6.000, Length = 7
# Episode 217: Total reward = -50.000, Length = 50
# Episode 218: Total reward = -50.000, Length = 50
# Episode 219: Total reward = -50.000, Length = 50
# Episode 220: Total reward = -50.000, Length = 50
# Episode 221: Total reward = -50.000, Length = 50
# Episode 222: Total reward = -50.000, Length = 50
# Episode 223: Total reward = -50.000, Length = 50
# Episode 224: Total reward = -50.000, Length = 50
# Episode 225: Total reward = -50.000, Length = 50
# Episode 226: Total reward = -1.000, Length = 2
# Episode 227: Total reward = -50.000, Length = 50
# Episode 228: Total reward = -50.000, Length = 50
# Episode 229: Total reward = -50.000, Length = 50
# Episode 230: Total reward = -50.000, Length = 50
# Episode 231: Total reward = -50.000, Length = 50
# Episode 232: Total reward = -50.000, Length = 50
# Episode 233: Total reward = -50.000, Length = 50
# Episode 234: Total reward = -50.000, Length = 50
# Episode 235: Total reward = -50.000, Length = 50
# Episode 236: Total reward = -50.000, Length = 50
# Episode 237: Total reward = -50.000, Length = 50
# Episode 238: Total reward = -50.000, Length = 50
# Episode 239: Total reward = -50.000, Length = 50
# Episode 240: Total reward = -3.000, Length = 4
# Episode 241: Total reward = -50.000, Length = 50
# Episode 242: Total reward = -50.000, Length = 50
# Episode 243: Total reward = -50.000, Length = 50
# Episode 244: Total reward = -50.000, Length = 50
# Episode 245: Total reward = -50.000, Length = 50
# Episode 246: Total reward = -50.000, Length = 50
# Episode 247: Total reward = -50.000, Length = 50
# Episode 248: Total reward = -50.000, Length = 50
# Episode 249: Total reward = -50.000, Length = 50
# Episode 250: Total reward = -50.000, Length = 50
# Episode 251: Total reward = -50.000, Length = 50
# Episode 252: Total reward = -50.000, Length = 50
# Episode 253: Total reward = -50.000, Length = 50
# Episode 254: Total reward = -50.000, Length = 50
# Episode 255: Total reward = -50.000, Length = 50
# Episode 256: Total reward = -50.000, Length = 50
# Episode 257: Total reward = -50.000, Length = 50
# Episode 258: Total reward = -50.000, Length = 50
# Episode 259: Total reward = -50.000, Length = 50
# Episode 260: Total reward = -50.000, Length = 50
# Episode 261: Total reward = -50.000, Length = 50
# Episode 262: Total reward = -50.000, Length = 50
# Episode 263: Total reward = -50.000, Length = 50
# Episode 264: Total reward = -50.000, Length = 50
# Episode 265: Total reward = -50.000, Length = 50
# Episode 266: Total reward = -50.000, Length = 50
# Episode 267: Total reward = -50.000, Length = 50
# Episode 268: Total reward = -50.000, Length = 50
# Episode 269: Total reward = -50.000, Length = 50
# Episode 270: Total reward = -50.000, Length = 50
# Episode 271: Total reward = -50.000, Length = 50
# Episode 272: Total reward = -50.000, Length = 50
# Episode 273: Total reward = -50.000, Length = 50
# Episode 274: Total reward = -2.000, Length = 3
# Episode 275: Total reward = -50.000, Length = 50
# Episode 276: Total reward = -50.000, Length = 50
# Episode 277: Total reward = -50.000, Length = 50
# Episode 278: Total reward = -50.000, Length = 50
# Episode 279: Total reward = -50.000, Length = 50
# Episode 280: Total reward = -50.000, Length = 50
# ...
# Episode 637: Total reward = 0.000, Length = 1
# Episode 638: Total reward = -50.000, Length = 50
# Episode 639: Total reward = -50.000, Length = 50
# Episode 640: Total reward = -50.000, Length = 50
# Episode 641: Total reward = -50.000, Length = 50
#
# Timestep 30000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -50.000, Success rate: 0.000
# ---------------------------------------
# Trial completed. Final success rate: 0.000
#
# ==== Best SAC_her Parameters ====
# Success Rate: 0.200
# Parameters: {'hidden_dim': 64, 'lr': 0.0005, 'gamma': 0.9293999096631801, 'tau': 0.02, 'alpha': 0.16036170650970208, 'automatic_entropy_tuning': True, 'batch_size': 32, 'buffer_size': 200000, 'learning_starts': 500}
#
# ==== Best SAC + HER Parameters ====
# Success Rate: 0.2
# hidden_dim: 64
# lr: 0.0005
# gamma: 0.9293999096631801
# tau: 0.02
# alpha: 0.16036170650970208
# automatic_entropy_tuning: True
# batch_size: 32
# buffer_size: 200000
# learning_starts: 500
#
# ==== Running TD3_HER ====
# ====================
# Running random search for td3 with HER
# ====================
# ---------------------------------------
# Environment: PandaReach-v3
# Observation Space: Dict('achieved_goal': Box(-10.0, 10.0, (3,), float32), 'desired_goal': Box(-10.0, 10.0, (3,), float32), 'observation': Box(-10.0, 10.0, (6,), float32))
# Action Space: Box(-1.0, 1.0, (3,), float32)
# Action Space High: [1. 1. 1.]
# Action Space Low: [-1. -1. -1.]
# ---------------------------------------
#
# ==== Running Random Search for TD3 with HER ====
#
# TD3 Trial 1/2
# Parameters: {'hidden_dim': 128, 'gamma': 0.9089722842272857, 'tau': 0.02, 'policy_noise': 0.16964520052684084, 'noise_clip': 0.46843790881683245, 'policy_freq': 3, 'exploration_noise': 0.06549261962884971, 'batch_size': 64, 'buffer_size': 100000, 'learning_starts': 0}
# Episode 1: Total reward = -50.000, Length = 50
# Episode 2: Total reward = -50.000, Length = 50
# Episode 3: Total reward = -50.000, Length = 50
# Episode 4: Total reward = -50.000, Length = 50
# Episode 5: Total reward = -50.000, Length = 50
# Episode 6: Total reward = -50.000, Length = 50
# Episode 7: Total reward = -50.000, Length = 50
# Episode 8: Total reward = -50.000, Length = 50
# Episode 9: Total reward = -50.000, Length = 50
# Episode 10: Total reward = -50.000, Length = 50
# Episode 11: Total reward = -50.000, Length = 50
# Episode 12: Total reward = -50.000, Length = 50
# Episode 13: Total reward = -50.000, Length = 50
# Episode 14: Total reward = 0.000, Length = 1
# Episode 15: Total reward = -6.000, Length = 7
# Episode 16: Total reward = -50.000, Length = 50
# Episode 17: Total reward = -50.000, Length = 50
# Episode 18: Total reward = -50.000, Length = 50
# Episode 19: Total reward = -50.000, Length = 50
# Episode 20: Total reward = -50.000, Length = 50
# Episode 21: Total reward = -50.000, Length = 50
# Episode 22: Total reward = 0.000, Length = 1
# Episode 23: Total reward = -50.000, Length = 50
# Episode 24: Total reward = -50.000, Length = 50
# Episode 25: Total reward = -50.000, Length = 50
# Episode 26: Total reward = -50.000, Length = 50
# Episode 27: Total reward = 0.000, Length = 1
# Episode 28: Total reward = -50.000, Length = 50
# Episode 29: Total reward = -50.000, Length = 50
# Episode 30: Total reward = -50.000, Length = 50
# Episode 31: Total reward = -9.000, Length = 10
# Episode 32: Total reward = -50.000, Length = 50
# Episode 33: Total reward = -50.000, Length = 50
# Episode 34: Total reward = -50.000, Length = 50
# Episode 35: Total reward = -50.000, Length = 50
# Episode 36: Total reward = -50.000, Length = 50
# Episode 37: Total reward = -50.000, Length = 50
# Episode 38: Total reward = -50.000, Length = 50
# Episode 39: Total reward = -50.000, Length = 50
# Episode 40: Total reward = -50.000, Length = 50
# Episode 41: Total reward = -50.000, Length = 50
# Episode 42: Total reward = -50.000, Length = 50
# Episode 43: Total reward = -50.000, Length = 50
# Episode 44: Total reward = -50.000, Length = 50
# Episode 45: Total reward = -50.000, Length = 50
# Episode 46: Total reward = -50.000, Length = 50
# Episode 47: Total reward = -50.000, Length = 50
# Episode 48: Total reward = -50.000, Length = 50
# Episode 49: Total reward = -9.000, Length = 10
# Episode 50: Total reward = -50.000, Length = 50
# Episode 51: Total reward = -50.000, Length = 50
# Episode 52: Total reward = -50.000, Length = 50
# Episode 53: Total reward = -50.000, Length = 50
# Episode 54: Total reward = -50.000, Length = 50
# Episode 55: Total reward = -50.000, Length = 50
# Episode 56: Total reward = -50.000, Length = 50
# Episode 57: Total reward = -50.000, Length = 50
# Episode 58: Total reward = -50.000, Length = 50
# Episode 59: Total reward = -50.000, Length = 50
# Episode 60: Total reward = -50.000, Length = 50
# Episode 61: Total reward = -50.000, Length = 50
# Episode 62: Total reward = -50.000, Length = 50
# Episode 63: Total reward = -50.000, Length = 50
# Episode 64: Total reward = -50.000, Length = 50
# Episode 65: Total reward = -50.000, Length = 50
# Episode 66: Total reward = -50.000, Length = 50
# Episode 67: Total reward = -50.000, Length = 50
# Episode 68: Total reward = -50.000, Length = 50
# Episode 69: Total reward = -50.000, Length = 50
# Episode 70: Total reward = -50.000, Length = 50
# Episode 71: Total reward = -50.000, Length = 50
# Episode 72: Total reward = -50.000, Length = 50
# Episode 73: Total reward = -50.000, Length = 50
# Episode 74: Total reward = -50.000, Length = 50
# Episode 75: Total reward = -50.000, Length = 50
# Episode 76: Total reward = -50.000, Length = 50
# Episode 77: Total reward = -50.000, Length = 50
# Episode 78: Total reward = -50.000, Length = 50
# Episode 79: Total reward = -50.000, Length = 50
# Episode 80: Total reward = -50.000, Length = 50
# Episode 81: Total reward = -50.000, Length = 50
# Episode 82: Total reward = -50.000, Length = 50
# Episode 83: Total reward = -50.000, Length = 50
# Episode 84: Total reward = -50.000, Length = 50
# Episode 85: Total reward = -50.000, Length = 50
# Episode 86: Total reward = -4.000, Length = 5
# Episode 87: Total reward = -50.000, Length = 50
# Episode 88: Total reward = -9.000, Length = 10
# Episode 89: Total reward = -9.000, Length = 10
# Episode 90: Total reward = -50.000, Length = 50
# Episode 91: Total reward = -50.000, Length = 50
# Episode 92: Total reward = -50.000, Length = 50
# Episode 93: Total reward = -50.000, Length = 50
# Episode 94: Total reward = -50.000, Length = 50
# Episode 95: Total reward = -50.000, Length = 50
# Episode 96: Total reward = -50.000, Length = 50
# Episode 97: Total reward = -50.000, Length = 50
# Episode 98: Total reward = -50.000, Length = 50
# Episode 99: Total reward = -50.000, Length = 50
# Episode 100: Total reward = -6.000, Length = 7
# Episode 101: Total reward = -50.000, Length = 50
# Episode 102: Total reward = -50.000, Length = 50
# Episode 103: Total reward = -50.000, Length = 50
# Episode 104: Total reward = -50.000, Length = 50
# Episode 105: Total reward = -50.000, Length = 50
# Episode 106: Total reward = -50.000, Length = 50
# Episode 107: Total reward = -50.000, Length = 50
# Episode 108: Total reward = -50.000, Length = 50
#
# Timestep 5000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -45.800, Success rate: 0.100
# ---------------------------------------
# Episode 109: Total reward = -50.000, Length = 50
# Episode 110: Total reward = -50.000, Length = 50
# Episode 111: Total reward = -50.000, Length = 50
# Episode 112: Total reward = -50.000, Length = 50
# Episode 113: Total reward = -50.000, Length = 50
# Episode 114: Total reward = -50.000, Length = 50
# Episode 115: Total reward = -50.000, Length = 50
# Episode 116: Total reward = -50.000, Length = 50
# Episode 117: Total reward = -50.000, Length = 50
# Episode 118: Total reward = -50.000, Length = 50
# Episode 119: Total reward = -50.000, Length = 50
# Episode 120: Total reward = -50.000, Length = 50
# Episode 121: Total reward = -50.000, Length = 50
# Episode 122: Total reward = -50.000, Length = 50
# Episode 123: Total reward = -50.000, Length = 50
# Episode 124: Total reward = -50.000, Length = 50
# Episode 125: Total reward = -50.000, Length = 50
# Episode 126: Total reward = -50.000, Length = 50
# Episode 127: Total reward = -50.000, Length = 50
# Episode 128: Total reward = -50.000, Length = 50
# Episode 129: Total reward = -50.000, Length = 50
# Episode 130: Total reward = -50.000, Length = 50
# Episode 131: Total reward = -50.000, Length = 50
# Episode 132: Total reward = -50.000, Length = 50
# Episode 133: Total reward = -50.000, Length = 50
# Episode 134: Total reward = -17.000, Length = 18
# Episode 135: Total reward = -29.000, Length = 30
# Episode 136: Total reward = -50.000, Length = 50
# Episode 137: Total reward = -50.000, Length = 50
# Episode 138: Total reward = -50.000, Length = 50
# Episode 139: Total reward = -50.000, Length = 50
# Episode 140: Total reward = -50.000, Length = 50
# Episode 141: Total reward = -50.000, Length = 50
# Episode 142: Total reward = -50.000, Length = 50
# Episode 143: Total reward = -50.000, Length = 50
# Episode 144: Total reward = -1.000, Length = 2
# Episode 145: Total reward = 0.000, Length = 1
# Episode 146: Total reward = -50.000, Length = 50
# Episode 147: Total reward = -50.000, Length = 50
# Episode 148: Total reward = -50.000, Length = 50
# Episode 149: Total reward = -50.000, Length = 50
# Episode 150: Total reward = -50.000, Length = 50
# Episode 151: Total reward = -50.000, Length = 50
# Episode 152: Total reward = -50.000, Length = 50
# Episode 153: Total reward = -50.000, Length = 50
# Episode 154: Total reward = -50.000, Length = 50
# Episode 155: Total reward = -50.000, Length = 50
# Episode 156: Total reward = -50.000, Length = 50
# Episode 157: Total reward = -50.000, Length = 50
# Episode 158: Total reward = 0.000, Length = 1
# Episode 159: Total reward = -50.000, Length = 50
# Episode 160: Total reward = 0.000, Length = 1
# Episode 161: Total reward = -50.000, Length = 50
# Episode 162: Total reward = -50.000, Length = 50
# Episode 163: Total reward = -50.000, Length = 50
# Episode 164: Total reward = -50.000, Length = 50
# Episode 165: Total reward = -50.000, Length = 50
# Episode 166: Total reward = -50.000, Length = 50
# Episode 167: Total reward = -50.000, Length = 50
# Episode 168: Total reward = -50.000, Length = 50
# Episode 169: Total reward = -50.000, Length = 50
# Episode 170: Total reward = -1.000, Length = 2
# Episode 171: Total reward = -50.000, Length = 50
# Episode 172: Total reward = -50.000, Length = 50
# Episode 173: Total reward = -50.000, Length = 50
# Episode 174: Total reward = -50.000, Length = 50
# Episode 175: Total reward = -50.000, Length = 50
# Episode 176: Total reward = -50.000, Length = 50
# Episode 177: Total reward = -50.000, Length = 50
# Episode 178: Total reward = -50.000, Length = 50
# Episode 179: Total reward = -50.000, Length = 50
# Episode 180: Total reward = -50.000, Length = 50
# Episode 181: Total reward = -50.000, Length = 50
# Episode 182: Total reward = -50.000, Length = 50
# Episode 183: Total reward = -50.000, Length = 50
# Episode 184: Total reward = -50.000, Length = 50
# Episode 185: Total reward = -50.000, Length = 50
# Episode 186: Total reward = -50.000, Length = 50
# Episode 187: Total reward = -50.000, Length = 50
# Episode 188: Total reward = -50.000, Length = 50
# Episode 189: Total reward = -50.000, Length = 50
# Episode 190: Total reward = -50.000, Length = 50
# Episode 191: Total reward = -50.000, Length = 50
# Episode 192: Total reward = -50.000, Length = 50
# Episode 193: Total reward = -50.000, Length = 50
# Episode 194: Total reward = -50.000, Length = 50
# Episode 195: Total reward = -50.000, Length = 50
# Episode 196: Total reward = 0.000, Length = 1
# Episode 197: Total reward = -50.000, Length = 50
# Episode 198: Total reward = -50.000, Length = 50
# Episode 199: Total reward = -50.000, Length = 50
# Episode 200: Total reward = -50.000, Length = 50
# Episode 201: Total reward = -50.000, Length = 50
# Episode 202: Total reward = -50.000, Length = 50
# Episode 203: Total reward = -50.000, Length = 50
# Episode 204: Total reward = -50.000, Length = 50
# Episode 205: Total reward = -3.000, Length = 4
# Episode 206: Total reward = -50.000, Length = 50
# Episode 207: Total reward = -50.000, Length = 50
# Episode 208: Total reward = -50.000, Length = 50
# Episode 209: Total reward = -50.000, Length = 50
# Episode 210: Total reward = -50.000, Length = 50
# Episode 211: Total reward = -50.000, Length = 50
# Episode 212: Total reward = -50.000, Length = 50
# Episode 213: Total reward = 0.000, Length = 1
# Episode 214: Total reward = -50.000, Length = 50
# Episode 215: Total reward = -50.000, Length = 50
# Episode 216: Total reward = -50.000, Length = 50
# Episode 217: Total reward = -50.000, Length = 50
#
# Timestep 10000/30000
# ---------------------------------------
# Evaluation over 10 episodes: -50.000, Success rate: 0.000
# ---------------------------------------
# Episode 218: Total reward = -50.000, Length = 50
# Episode 219: Total reward = -50.000, Length = 50
# Episode 220: Total reward = -50.000, Length = 50
# Episode 221: Total reward = -50.000, Length = 50
# Episode 222: Total reward = -50.000, Length = 50
# Episode 223: Total reward = -50.000, Length = 50
# Episode 224: Total reward = -50.000, Length = 50
# Episode 225: Total reward = -50.000, Length = 50
# Episode 226: Total reward = -50.000, Length = 50
# Episode 227: Total reward = -50.000, Length = 50
# Episode 228: Total reward = -50.000, Length = 50
# Episode 229: Total reward = -50.000, Length = 50
# Episode 230: Total reward = -1.000, Length = 2
# Episode 231: Total reward = -50.000, Length = 50
# Episode 232: Total reward = -50.000, Length = 50
# Episode 233: Total reward = -50.000, Length = 50
# Episode 234: Total reward = -50.000, Length = 50
# Episode 235: Total reward = -50.000, Length = 50
# Episode 236: Total reward = -50.000, Length = 50
# Episode 237: Total reward = -50.000, Length = 50
# Episode 238: Total reward = -50.000, Length = 50
# Episode 239: Total reward = -50.000, Length = 50
# Episode 240: Total reward = -50.000, Length = 50
# Episode 241: Total reward = -50.000, Length = 50
# Episode 242: Total reward = -50.000, Length = 50
# Episode 243: Total reward = -50.000, Length = 50
# Episode 244: Total reward = -50.000, Length = 50
# Episode 245: Total reward = -50.000, Length = 50
# Episode 246: Total reward = -50.000, Length = 50
# Episode 247: Total reward = -50.000, Length = 50
# Episode 248: Total reward = -50.000, Length = 50
# Episode 249: Total reward = -50.000, Length = 50
# Episode 250: Total reward = -50.000, Length = 50
# Episode 251: Total reward = -50.000, Length = 50
# Episode 252: Total reward = -50.000, Length = 50
# Episode 253: Total reward = -50.000, Length = 50
# Episode 254: Total reward = -50.000, Length = 50
# Episode 255: Total reward = -50.000, Length = 50
# Episode 256: Total reward = -50.000, Length = 50
# Episode 257: Total reward = 0.000, Length = 1
# Episode 258: Total reward = -50.000, Length = 50
# Episode 259: Total reward = -50.000, Length = 50
# Episode 260: Total reward = -50.000, Length = 50
# Episode 261: Total reward = -50.000, Length = 50
# Episode 262: Total reward = -50.000, Length = 50
# Episode 263: Total reward = -50.000, Length = 50
# Episode 264: Total reward = -50.000, Length = 50
# Episode 265: Total reward = -50.000, Length = 50
# Episode 266: Total reward = -50.000, Length = 50
# Episode 267: Total reward = -50.000, Length = 50
# Episode 268: Total reward = -50.000, Length = 50
# Episode 269: Total reward = -50.000, Length = 50
# Episode 270: Total reward = -50.000, Length = 50
# Episode 271: Total reward = -50.000, Length = 50
# Episode 272: Total reward = -50.000, Length = 50
# Episode 273: Total reward = -50.000, Length = 50
# Episode 274: Total reward = -50.000, Length = 50
# Episode 275: Total reward = -50.000, Length = 50
# Episode 276: Total reward = -50.000, Length = 50
# Episode 277: Total reward = -50.000, Length = 50
# Episode 278: Total reward = -50.000, Length = 50
# Episode 279: Total reward = -50.000, Length = 50
# Episode 280: Total reward = -50.000, Length = 50
# Episode 281: Total reward = -50.000, Length = 50
# Episode 282: Total reward = -50.000, Length = 50
# Episode 283: Total reward = -50.000, Length = 50
# Episode 284: Total reward = -50.000, Length = 50
# Episode 285: Total reward = -50.000, Length = 50
# Episode 286: Total reward = -50.000, Length = 50
# KeyboardInterrupt
